# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sessions = range(105, 115)
entropies = [0.330811090278, 0.373348472205,
             0.352464288866, 0.301604209587,
             0.347244242864, 0.393772068888,
             0.333154183887, 0.292677283744,
             0.206510264465, 0.21753817906]

# %%
plt.plot(sessions, entropies)
plt.title("Average Entropy for each Congressional Session (Unweighted)")
plt.ylabel("Entropy")
plt.xlabel("Session")

# %%
sessions_weighted = range(105, 115)
entropies_weighted = [0.299695756409, 0.386751142518, 
                      0.327316898618, 0.318213290216,
                      0.377984628786, 0.383900025222,
                      0.309564365789, 0.269291877138,
                      0.237469316932, 0.240052381041]

# %%
plt.plot(sessions_weighted, entropies_weighted)
plt.title("Average Entropy for each Congressional Session (Weighted)")
plt.ylabel("Entropy")
plt.xlabel("Session")
